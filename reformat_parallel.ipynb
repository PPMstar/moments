# %%
import shutil
import os
import subprocess
import pkg_resources
import logging
import multiprocessing as mp
import sys
sys.path.insert(0, '/home/jerichoo/jupyter_py3/lib/python2.7/site-packages/')
from joblib import Parallel, delayed
sys.path.insert(0,'./moments/moments/utils')
sys.path.insert(0,'./moments/')
import moments.core.ppmdir
import fpp

log = logging.getLogger(__name__)
log.propagate = False
ch = logging.StreamHandler()
log.addHandler(ch)
log.setLevel(logging.INFO)

def reformat_hv(ftype,dump,info):
    
    #log.info('%s %s  being processed....' % (ftype, dump))
    
    if os.path.isfile(info.hv_format.format(ftype=ftype, dump=dump, ext=".hv")):
        log.info('%s %s  already has hv file overwrite=True to overwrite' % (ftype, dump))
        return
    
    for file in info.source.get_dumpfiles(ftype, dump):
        base, ext = os.path.splitext(file)
        RBO_in_ftype = None
        for key, value in info.RBO_input_map.items():
            if ftype in key:
                RBO_in_ftype = value
                break
        if RBO_in_ftype is not None:
            nbytes = os.path.getsize(file)
            nbytes_theoretical = (info.resolutionx*info.resolutiony*info.resolutionz)/info.nteams
            out_file = info.hv_processing_format.format(ftype=ftype, RBO_in_ftype=RBO_in_ftype, dump=dump, ext=ext)
            
            # code to sort out the restarts
            if ftype == 'FV-hires':
                nbytes_theoretical *= info.nteams # don't know if this is true
            if nbytes != nbytes_theoretical:
                if nbytes < nbytes_theoretical:
                    log.info('bytes: %s this is not the right size should be %s %s %s %s'\
                             % (nbytes, '> ', nbytes_theoretical, ftype, dump))
                    break
                if nbytes > nbytes_theoretical: 
                    log.info('bytes: %s %s %s %s %s truncated' % (nbytes, '> ', nbytes_theoretical, ftype, dump))
                    out_dir = os.path.dirname(out_file)
                    if not os.path.exists(out_dir):
                        try:
                            os.makedirs(out_dir)
                        except:
                            log.info('Trying to write to a dir while it was created') 

                    truncate_command = ["tail","-c",str(nbytes_theoretical),file,">",out_file]
                    command = subprocess.Popen(' '.join(truncate_command), shell=True)
                    command.wait()
            else:
                _copy_file(file, out_file)
        else:
            log.info('cannot convert {ftype} files into hv'.format(ftype=ftype))
            _copy_file(file, info.hv_other_format.format(ftype=ftype, RBO_in_ftype=RBO_in_ftype, dump=dump, ext=ext))
            break

    for RBO_key in info.RBO_input_map.keys():         
        if ftype in RBO_key:
            settings = dict((key, info.source_code_definitions.get(key, value)) for key, value in info.RBO_default.items())
            settings.update(info.RBO_settings[RBO_key])
            
            code = fpp.define(info.RBO_source, **settings)
            with open(info.hv_source_format.format(ftype=ftype,dump=dump), "w") as fout:
                fout.write(code)

            ftype_RBO_source = info.hv_source_format.format(ftype=ftype,dump=dump)
            ftype_RBO, _ = os.path.splitext(ftype_RBO_source)
            compile = subprocess.Popen(["ifort", ftype_RBO_source] + info.RBO_compile_flags + [ftype_RBO])
            compile.wait()

            processing_dir = os.path.dirname(info.hv_processing_format.format(ftype=ftype, RBO_in_ftype="", dump="", ext=""))
            RBO_command = [ftype_RBO, str(int(dump)), str(int(dump))]

            RBO_compute = subprocess.Popen(RBO_command, cwd=processing_dir)
            RBO_compute.wait()

            bob2hv_ftype = None
            for key, value in info.bob2hv_input_map.items():
                if ftype in key:
                    bob2hv_ftype = value
                    break

            if bob2hv_ftype is not None:                
                resolutionx = info.source_code_definitions["nnxteams"]*info.source_code_definitions["nntxbricks"]*info.source_code_definitions["nnnnx"]
                resolutiony = info.source_code_definitions["nnyteams"]*info.source_code_definitions["nntybricks"]*info.source_code_definitions["nnnny"]
                resolutionz = info.source_code_definitions["nnzteams"]*info.source_code_definitions["nntzbricks"]*info.source_code_definitions["nnnnz"]
                if not any([ftype in type for type in info.is_hires]):
                    resolutionx = int(resolutionx/2.0)
                    resolutiony = int(resolutiony/2.0)
                    resolutionz = int(resolutionz/2.0)
                    RBO_file = info.hv_processing_format.format(ftype=ftype, RBO_in_ftype=bob2hv_ftype, dump=dump, ext=".bobaaa")
                else:
                    RBO_file = info.hv_processing_format.format(ftype=ftype, RBO_in_ftype=bob2hv_ftype, dump=dump, ext=".bob8aaa")
            
                bob2hv_command = [info.bob2hv_path, str(resolutionx), str(resolutiony), str(int(resolutionz/2.0)), RBO_file, "-t",
                                  str(info.source_code_definitions["nnxteams"]), str(info.source_code_definitions["nnyteams"]), str(2*info.source_code_definitions["nnzteams"]), "-s", "128"]

                bob2hv = subprocess.Popen(bob2hv_command, cwd=processing_dir)
                bob2hv.wait()

                hv_file, _ = os.path.splitext(RBO_file)
                try:
                    _move_file(hv_file + ".hv", info.hv_format.format(ftype=ftype, dump=dump, ext=".hv"))
                except IOError as error:
                    log.error('No .hv file was made for {ftype}'.format(ftype=info.hv_format.format(ftype=ftype, dump=dump, ext=".hv")))
                    log.error('Either {RBO} or {bob} command failed'.format(RBO=RBO_command,bob =bob2hv_command))
                    
                    
def _copy_file(source, target):
    target_dir = os.path.dirname(target)
    if not os.path.exists(target_dir):
        try:
            os.makedirs(target_dir)
        except:
            log.info('Trying to write to a dir while it was created') 
    try:
        if not os.path.exists(target):
            shutil.copy(source, target)
            pass
    except IOError as error:
        print(error)

def _move_file(source, target):
    target_dir = os.path.dirname(target)
    if not os.path.exists(target_dir):
        try:
            os.makedirs(target_dir)
        except:
            log.info('Trying to write to a dir while it was created') 
    if not os.path.exists(target):
        shutil.move(source, target)

class reformation_info(object):
    
    def __init__(self,source_dir,target_dir,all_files=False,max_dumps=None):
        
        #RBO: ReformatBigOutput
        self.max_dumps = max_dumps
        self.all_files = all_files

        if isinstance(source_dir, str):
            self.source_dir = os.path.abspath(source_dir) + "/"
            self.source = moments.core.ppmdir.get_ppmdir(source_dir, all_files)
        else:
            self.source = source_dir
            self.source_dir = source._dir

        self.target_dir = os.path.abspath(target_dir) + "/"
        '''
        self.profile_format = self.target_dir + "{ftype}/{ftype}-{dump}{ext}"
        self.bobfile_format = self.target_dir + "{ftype}/{dump}{ext}" #chan
        self.ppmin_format = self.target_dir + "post/{fname}"
        self.hv_format = self.target_dir + "HV/{ftype}/{dump}{ext}"
        self.hv_processing_format = self.target_dir + "HV_processing/{ftype}/{RBO_in_ftype}-{dump}{ext}"
        self.hv_source_format = self.target_dir + "HV_processing/{ftype}{dump}_xreformat64_all.F"
        '''
        self.profile_format = self.target_dir + "{ftype}/{ftype}-{dump}{ext}"
        self.bobfile_format = self.target_dir + "{ftype}/{dump}/{ftype}-{dump}{ext}" #chan
        self.ppmin_format = self.target_dir + "post/{fname}"
        self.hv_format = self.target_dir + "HV/{ftype}/{ftype}-{dump}{ext}"
        self.hv_processing_format = self.target_dir + "HV_processing/{ftype}/{RBO_in_ftype}-{dump}{ext}"
        self.hv_other_format = self.target_dir + "other_bob/{ftype}/{RBO_in_ftype}-{dump}{ext}"
        self.hv_source_format = self.target_dir + "HV_processing/{ftype}{dump}_xreformat64_all.F"

        self.RBO_source = pkg_resources.resource_string("moments.utils", "/bin/ReformatBigOutputargs.F")
        self.RBO_compile_flags = ["-mcmodel=medium", "-i-dynamic", "-tpp7", "-xT", "-fpe0",
                             "-w", "-ip", "-Ob2", "-pc32", "-i8", "-auto", "-fpp2", "-o"]

        self.RBO_input_map = {"FVandMoms":"FVandMoms48",
                         "FV-hires":"FV-hires01",
                         "TanhUY":"TanhUY--001",
                         "TanhDivU":"TanhDivU-01",
                         "Lg10Vort":"Lg10Vort-01",
                         "Lg10ENUCbyP":"Lg10ENUCbyP"}

        self.RBO_default = {"isBoB8":0, "isBoB":0, "isMom":0, "isvort":0,
                       "isdivu":0, "isuy":0, "isenuc":0, "nnxteams":0,
                       "nnyteams":0, "nnzteams":0, "nntxbricks":0,
                       "nntybricks":0, "nntzbricks":0, "nnnnx":0,
                       "nnnny":0, "nnnnz":0}

        self.RBO_settings = {"FVandMoms":{"isMom":1},
                        "FV-hires":{"isBoB8":1},
                        "TanhUY":{"isBoB":1, "isuy":1},
                        "TanhDivU":{"isBoB":1, "isdivu":1},
                        "Lg10Vort":{"isBoB":1, "isvort":1},
                        "Lg10ENUCbyP":{"isBoB":1, "isenuc":1}}

        self.bob2hv_path = os.path.abspath(pkg_resources.resource_filename("moments.utils", "/bin/bob2hv"))

        self.is_hires = ["FV-hires"]

        self.bob2hv_input_map = {"FVandMoms":"FVandMomt48",
                            "FV-hires":"FV-hiret01",
                            "TanhUY":"TanhUY-0001",
                            "TanhDivU":"TanhDivV-01",
                            "Lg10Vort":"Lg10Voru-01",
                            "Lg10ENUCbyP":"Lg10ENVCbyP"}

        self.profiles = []
        self.bobfiles = []
        self.ppminfiles = []
        self.hvfiles = []

        #analyze PPM2F source code
        for file in self.source.get_source_code():
            if file.endswith(source_dir[-2:]+'.F'):
                log.info(file, ' will be used as the source file')
                source_code = file
                break
                
        if 'source_code' not in locals():
            source_code = self.source.get_source_code()[0]
            log.info('%s will be used as the source file' % (file))    
        self.source_code_definitions = fpp.preprocess(source_code)
        if ("nnzteams" in self.source_code_definitions) and ("nnxteams" not in self.source_code_definitions):
            self.source_code_definitions["nnxteams"] = self.source_code_definitions["nnzteams"]

        if ("nntzbricks" in self.source_code_definitions) and ("nntxbricks" not in self.source_code_definitions):
            self.source_code_definitions["nntxbricks"] = self.source_code_definitions["nntzbricks"]

        if ("nnnnz" in self.source_code_definitions) and ("nnnnx" not in self.source_code_definitions):
            self.source_code_definitions["nnnnx"] = self.source_code_definitions["nnnnz"] 
        #move files into HV_processing
        self.resolutionx = self.source_code_definitions["nnxteams"]*self.source_code_definitions["nntxbricks"]\
            *self.source_code_definitions["nnnnx"]
        self.resolutiony = self.source_code_definitions["nnyteams"]*self.source_code_definitions["nntybricks"]\
            *self.source_code_definitions["nnnny"]
        self.resolutionz = self.source_code_definitions["nnzteams"]*self.source_code_definitions["nntzbricks"]\
            *self.source_code_definitions["nnnnz"]
        self.nteams = self.source_code_definitions["nnxteams"]*self.source_code_definitions["nnyteams"]\
            *self.source_code_definitions["nnzteams"]
        
        print self.resolutionx, self.nteams
        
        self.profiles = self.source.get_profile_types()
        for ftype in self.source.get_bobfile_types():
            if "FVandMoms" in ftype:
                self.bobfiles.append(ftype)
            else:
                self.hvfiles.append(ftype)
        self.ppminfiles = self.source.get_ppminfile_types()
    
def copy_source_code(info,file):
    
    #for file in info.source.get_source_code() + info.source.get_compile_script() + info.source.get_jobscript() + info.source.get_other_files():
    fname = file.replace(info.source_dir, "")
    _copy_file(file, info.target_dir + fname)
        
def copy_profiles(info,ftype,dump):
    
    for file in info.source.get_dumpfiles(ftype, dump):
        base, ext = os.path.splitext(file)
        _copy_file(file, info.profile_format.format(ftype=ftype, dump=dump, ext=ext))
                
def copy_bobfiles(info,ftype,dump):
    
    for file in info.source.get_dumpfiles(ftype, dump):
        base, ext = os.path.splitext(file)
        _copy_file(file, info.bobfile_format.format(ftype=ftype, dump=dump, ext=ext))
                
def copy_ppminfiles(info):
    
    for ftype in info.ppminfiles:
        for i, dump in enumerate(info.source.get_dumps(ftype)):
            if info.max_dumps is not None:
                if i == info.max_dumps:
                    break
            for file in info.source.get_dumpfiles(ftype, dump):
                fname = os.path.basename(file)
                _copy_file(file, info.ppmin_format.format(fname=fname))

def reformat_parallel(source_dir,target_dir,all_files=False,max_dumps=None):
    
    #setting up a logger
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    ch.setFormatter(formatter)
    logs_dir = target_dir + '/reformatting_log'
    
    if not os.path.exists(logs_dir):
        os.makedirs(logs_dir)

    fh = logging.FileHandler(os.path.join(logs_dir, 'log_' + target_dir[-2:]))
    fh.setFormatter(formatter)
    log.addHandler(fh)
    
    info = reformation_info(source_dir,target_dir,all_files=all_files,max_dumps=None)
    
    # copy_only(info)
    other_files = (
                    info.source.get_source_code() 
                    + info.source.get_compile_script() 
                    + info.source.get_jobscript()
                    + info.source.get_other_files())
    
    copy_ppminfiles(info)
    
    num_cores = mp.cpu_count() #this always returns 32

    # Running the copy process in parallel
    Parallel(n_jobs=num_cores)(
        delayed(copy_source_code)(info,file) for file in other_files)
   
    Parallel(n_jobs=num_cores)(
        delayed(copy_profiles)(info,ftype,ndump) for ftype in info.profiles\
        for ndump in info.source.get_dumps(ftype))
    
    Parallel(n_jobs=num_cores)(
        delayed(copy_bobfiles)(info,ftype,ndump) for ftype in info.bobfiles\
        for ndump in info.source.get_dumps(ftype))
    
    # Running the hv transformation in parallel
    Parallel(n_jobs=num_cores)(
        delayed(reformat_hv)(ftype,ndump,info) for ftype in info.hvfiles\
        for ndump in info.source.get_dumps(ftype))
                        
    shutil.rmtree(os.path.dirname(info.hv_source_format.format(ftype="",dump="")))

# %% [markdown]
# ### Removing a run to redo it

# %%
#!rm -rf /home/jerichoo/projects/rrg-fherwig-ad/fherwig/PPM_processed/D/pPPM_D6/HV_processing/

# %% [markdown]
# ### Main Code

# %%
#for name in [8,15]:
#    try:
#in_dir = '/home/jerichoo/projects/rrg-fherwig-ad/fherwig/PPM_unprocessed/PPM_D5/' #.format(name)
#out_dir = '/home/jerichoo/projects/rrg-fherwig-ad/fherwig/PPM_processed/D/pPPM_D5' #.format(name)
in_dir = '/home/jerichoo/projects/rrg-fherwig-ad/fherwig/PPM_unprocessed/J/PPM_J8/' #.format(name)
out_dir = '/home/jerichoo/projects/rrg-fherwig-ad/fherwig/PPM_processed/J/pPPM_J8' #.format(name)
reformat_parallel(in_dir,out_dir,all_files = True)
#    except:
#        print('Didnt make hv for {}'.format(name))
# Out:
# 2017-12-11 14:35:46,434 - INFO - /home/jerichoo/projects/rrg-fherwig-ad/fherwig/PPM_unprocessed/J/PPM_J8/PPM2F-star_J8.F will be used as the source file
# Warning: Evaluation of preprocessor directive failed.
# 	"#define nnbsmax nnbuckets/5"
# Warning: Evaluation of preprocessor macros not implemented.
# 	"#define ea2h(a) rshift((a),32)"
# Warning: Evaluation of preprocessor macros not implemented.
# 	"#define ea2l(a) (a)"
# Warning: Evaluation of preprocessor directive failed.
# 	"#if isdtrace"
# 768 8

# %% [markdown]
# ### Check the file structures

# %%
def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
            
list_files(out_dir)
# Out:
# pPPM_D18/
#     restart0/
#     restart1/
#     HV/
#         TanhUY/
#         Lg10ENUCbyP/
#         Lg10Vort/
#         TanhDivU/
#         FV-hires/
#     RProfile/
#     FVandMoms48/
#         0071/
#         0150/
#         0110/
#         0122/
#         0118/
#         0152/
#         0117/
#         0215/
#         0154/
#         0171/
#         0202/
#         0160/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-790fd4e158e0> in <module>()
#       6         subindent = ' ' * 4 * (level + 1)
#       7
# ----> 8 list_files(out_dir)
#
# <ipython-input-6-790fd4e158e0> in list_files(startpath)
#       1 def list_files(startpath):
# ----> 2     for root, dirs, files in os.walk(startpath):
#       3         level = root.replace(startpath, '').count(os.sep)
#       4         indent = ' ' * 4 * (level)
#       5         print('{}{}/'.format(indent, os.path.basename(root)))
#
# /cvmfs/soft.computecanada.ca/nix/store/hl7fc4ff0w468k8rw0068f9k1md33vzq-python-2.7.13/lib/python2.7/os.pyc in walk(top, topdown, onerror, followlinks)
#     294         new_path = join(top, name)
#     295         if followlinks or not islink(new_path):
# --> 296             for x in walk(new_path, topdown, onerror, followlinks):
#     297                 yield x
#     298     if not topdown:
#
# /cvmfs/soft.computecanada.ca/nix/store/hl7fc4ff0w468k8rw0068f9k1md33vzq-python-2.7.13/lib/python2.7/os.pyc in walk(top, topdown, onerror, followlinks)
#     294         new_path = join(top, name)
#     295         if followlinks or not islink(new_path):
# --> 296             for x in walk(new_path, topdown, onerror, followlinks):
#     297                 yield x
#     298     if not topdown:
#
# /cvmfs/soft.computecanada.ca/nix/store/hl7fc4ff0w468k8rw0068f9k1md33vzq-python-2.7.13/lib/python2.7/os.pyc in walk(top, topdown, onerror, followlinks)
#     284     dirs, nondirs = [], []
#     285     for name in names:
# --> 286         if isdir(join(top, name)):
#     287             dirs.append(name)
#     288         else:
#
# /cvmfs/soft.computecanada.ca/nix/store/hl7fc4ff0w468k8rw0068f9k1md33vzq-python-2.7.13/lib/python2.7/genericpath.pyc in isdir(s)
#      47     """Return true if the pathname refers to an existing directory."""
#      48     try:
# ---> 49         st = os.stat(s)
#      50     except os.error:
#      51         return False
#
# KeyboardInterrupt:

# %% [markdown]
# ### Check the files were moved

# %%
import os

def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        for f in files[1:10]:
            print('{}{}'.format(subindent, f))
            
list_files(out_dir)
# Out:
# pPPM_D4/
#     restartg1.dmpbbb
#     Lg10Voru-01-0026.hv
#     FV-hiret01-0043.hv
#     restarta1.dmpaaa
#     Lg10Voru-01-0106.hv
#     FV-hiret01-0110.hv
#     Lg10Voru-01-0010.hv
#     FV-hiret01-0023.hv
#     TanhUY-0001-0057.hv
#     HV/
#         TanhUY/
#             TanhUY-0069.hv
#             TanhUY-0033.hv
#             TanhUY-0006.hv
#             TanhUY-0087.hv
#             TanhUY-0058.hv
#             TanhUY-0097.hv
#             TanhUY-0055.hv
#             TanhUY-0007.hv
#             TanhUY-0065.hv
#         Lg10Vort/
#             Lg10Vort-0095.hv
#             Lg10Vort-0126.hv
#             Lg10Vort-0046.hv
#             Lg10Vort-0117.hv
#             Lg10Vort-0091.hv
#             Lg10Vort-0028.hv
#             Lg10Vort-0140.hv
#             Lg10Vort-0000.hv
#             Lg10Vort-0053.hv
#         Lg10ENUCbyP/
#             Lg10ENUCbyP-0109.hv
#             Lg10ENUCbyP-0019.hv
#             Lg10ENUCbyP-0052.hv
#             Lg10ENUCbyP-0026.hv
#             Lg10ENUCbyP-0016.hv
#             Lg10ENUCbyP-0129.hv
#             Lg10ENUCbyP-0065.hv
#             Lg10ENUCbyP-0132.hv
#             Lg10ENUCbyP-0095.hv
#         FV-hires/
#             FV-hires-0063.hv
#             FV-hires-0088.hv
#             FV-hires-0090.hv
#             FV-hires-0092.hv
#             FV-hires-0072.hv
#             FV-hires-0053.hv
#             FV-hires-0102.hv
#             FV-hires-0054.hv
#             FV-hires-0075.hv
#         TanhDivU/
#             TanhDivU-0099.hv
#             TanhDivU-0116.hv
#             TanhDivU-0070.hv
#             TanhDivU-0126.hv
#             TanhDivU-0053.hv
#             TanhDivU-0087.hv
#             TanhDivU-0101.hv
#             TanhDivU-0119.hv
#             TanhDivU-0112.hv
#     reformatting_log/
#     YProfile/
#         YProfile-0000.bobaaa
#         YProfile-0114.bobaaa
#         YProfile-0034.bobaaa
#         YProfile-0051.bobaaa
#         YProfile-0032.bobaaa
#         YProfile-0026.bobaaa
#         YProfile-0028.bobaaa
#         YProfile-0079.bobaaa
#         YProfile-0029.bobaaa
#     FVandMoms48/
#         0101/
#             FVandMoms48-0101.bobaab
#             FVandMoms48-0101.bobaaa
#             FVandMoms48-0101.bobaba
#             FVandMoms48-0101.bobbba
#             FVandMoms48-0101.bobbbb
#             FVandMoms48-0101.bobabb
#             FVandMoms48-0101.bobbab
#         0083/
#             FVandMoms48-0083.bobbbb
#             FVandMoms48-0083.bobaba
#             FVandMoms48-0083.bobbba
#             FVandMoms48-0083.bobbab
#             FVandMoms48-0083.bobaaa
#             FVandMoms48-0083.bobabb
#             FVandMoms48-0083.bobbaa
#         0108/
#             FVandMoms48-0108.bobbba
#             FVandMoms48-0108.bobaab
#             FVandMoms48-0108.bobaaa
#             FVandMoms48-0108.bobbaa
#             FVandMoms48-0108.bobbab
#             FVandMoms48-0108.bobabb
#             FVandMoms48-0108.bobbbb
#         0098/
#             FVandMoms48-0098.bobbaa
#             FVandMoms48-0098.bobbbb
#             FVandMoms48-0098.bobaba
#             FVandMoms48-0098.bobbba
#             FVandMoms48-0098.bobaab
#             FVandMoms48-0098.bobbab
#             FVandMoms48-0098.bobabb
#         0065/
#             FVandMoms48-0065.bobaaa
#             FVandMoms48-0065.bobbab
#             FVandMoms48-0065.bobaab
#             FVandMoms48-0065.bobabb
#             FVandMoms48-0065.bobbaa
#             FVandMoms48-0065.bobbba
#             FVandMoms48-0065.bobbbb
#         0086/
#             FVandMoms48-0086.bobabb
#             FVandMoms48-0086.bobaba
#             FVandMoms48-0086.bobaaa
#             FVandMoms48-0086.bobbab
#             FVandMoms48-0086.bobbaa
#             FVandMoms48-0086.bobbbb
#             FVandMoms48-0086.bobbba
#         0071/
#             FVandMoms48-0071.bobbbb
#             FVandMoms48-0071.bobaaa
#             FVandMoms48-0071.bobbaa
#             FVandMoms48-0071.bobabb
#             FVandMoms48-0071.bobbba
#             FVandMoms48-0071.bobbab
#             FVandMoms48-0071.bobaab
#         0044/
#             FVandMoms48-0044.bobbaa
#             FVandMoms48-0044.bobaaa
#             FVandMoms48-0044.bobabb
#             FVandMoms48-0044.bobbab
#             FVandMoms48-0044.bobaab
#             FVandMoms48-0044.bobbba
#             FVandMoms48-0044.bobaba
#         0023/
#             FVandMoms48-0023.bobbba
#             FVandMoms48-0023.bobaaa
#             FVandMoms48-0023.bobaab
#             FVandMoms48-0023.bobbbb
#             FVandMoms48-0023.bobbaa
#             FVandMoms48-0023.bobabb
#             FVandMoms48-0023.bobaba
#         0113/
#             FVandMoms48-0113.bobaab
#             FVandMoms48-0113.bobaba
#             FVandMoms48-0113.bobbbb
#             FVandMoms48-0113.bobabb
#             FVandMoms48-0113.bobbab
#             FVandMoms48-0113.bobbba
#             FVandMoms48-0113.bobaaa
#         0046/
#             FVandMoms48-0046.bobbba
#             FVandMoms48-0046.bobabb
#             FVandMoms48-0046.bobbab
#             FVandMoms48-0046.bobaba
#             FVandMoms48-0046.bobbaa
#             FVandMoms48-0046.bobbbb
#             FVandMoms48-0046.bobaab
#         0057/
#             FVandMoms48-0057.bobbba
#             FVandMoms48-0057.bobaab
#             FVandMoms48-0057.bobabb
#             FVandMoms48-0057.bobbbb
#             FVandMoms48-0057.bobaba
#             FVandMoms48-0057.bobbaa
#             FVandMoms48-0057.bobbab
#         0104/
#             FVandMoms48-0104.bobaaa
#             FVandMoms48-0104.bobbab
#             FVandMoms48-0104.bobbbb
#             FVandMoms48-0104.bobaab
#             FVandMoms48-0104.bobbaa
#             FVandMoms48-0104.bobbba
#             FVandMoms48-0104.bobabb
#         0092/
#             FVandMoms48-0092.bobbaa
#             FVandMoms48-0092.bobbba
#             FVandMoms48-0092.bobaaa
#             FVandMoms48-0092.bobaab
#             FVandMoms48-0092.bobbab
#             FVandMoms48-0092.bobaba
#             FVandMoms48-0092.bobabb
#         0016/
#             FVandMoms48-0016.bobaab
#             FVandMoms48-0016.bobbba
#             FVandMoms48-0016.bobaaa
#             FVandMoms48-0016.bobbbb
#             FVandMoms48-0016.bobaba
#             FVandMoms48-0016.bobabb
#             FVandMoms48-0016.bobbaa
#         0010/
#             FVandMoms48-0010.bobbaa
#             FVandMoms48-0010.bobabb
#             FVandMoms48-0010.bobbba
#             FVandMoms48-0010.bobbab
#             FVandMoms48-0010.bobaaa
#             FVandMoms48-0010.bobaab
#             FVandMoms48-0010.bobaba
#         0039/
#             FVandMoms48-0039.bobbbb
#             FVandMoms48-0039.bobabb
#             FVandMoms48-0039.bobbaa
#             FVandMoms48-0039.bobbab
#             FVandMoms48-0039.bobaba
#             FVandMoms48-0039.bobbba
#             FVandMoms48-0039.bobaab
#         0111/
#             FVandMoms48-0111.bobbbb
#             FVandMoms48-0111.bobaba
#             FVandMoms48-0111.bobbab
#             FVandMoms48-0111.bobabb
#             FVandMoms48-0111.bobaab
#             FVandMoms48-0111.bobbaa
#             FVandMoms48-0111.bobbba
#         0103/
#             FVandMoms48-0103.bobbaa
#             FVandMoms48-0103.bobbbb
#             FVandMoms48-0103.bobabb
#             FVandMoms48-0103.bobaaa
#             FVandMoms48-0103.bobaba
#             FVandMoms48-0103.bobbab
#             FVandMoms48-0103.bobaab
#         0017/
#             FVandMoms48-0017.bobbaa
#             FVandMoms48-0017.bobabb
#             FVandMoms48-0017.bobbba
#             FVandMoms48-0017.bobaaa
#             FVandMoms48-0017.bobaba
#             FVandMoms48-0017.bobaab
#             FVandMoms48-0017.bobbab
#         0033/
#             FVandMoms48-0033.bobaaa
#             FVandMoms48-0033.bobbab
#             FVandMoms48-0033.bobbba
#             FVandMoms48-0033.bobabb
#             FVandMoms48-0033.bobaba
#             FVandMoms48-0033.bobbaa
#             FVandMoms48-0033.bobaab
#         0003/
#             FVandMoms48-0003.bobbbb
#             FVandMoms48-0003.bobabb
#             FVandMoms48-0003.bobaab
#             FVandMoms48-0003.bobbab
#             FVandMoms48-0003.bobbba
#             FVandMoms48-0003.bobbaa
#             FVandMoms48-0003.bobaaa
#         0095/
#             FVandMoms48-0095.bobaaa
#             FVandMoms48-0095.bobbbb
#             FVandMoms48-0095.bobabb
#             FVandMoms48-0095.bobbba
#             FVandMoms48-0095.bobbab
#             FVandMoms48-0095.bobaba
#             FVandMoms48-0095.bobbaa
#         0109/
#             FVandMoms48-0109.bobaab
#             FVandMoms48-0109.bobbba
#             FVandMoms48-0109.bobbaa
#             FVandMoms48-0109.bobbab
#             FVandMoms48-0109.bobaba
#             FVandMoms48-0109.bobaaa
#             FVandMoms48-0109.bobbbb
#         0094/
#             FVandMoms48-0094.bobbaa
#             FVandMoms48-0094.bobabb
#             FVandMoms48-0094.bobbbb
#             FVandMoms48-0094.bobbab
#             FVandMoms48-0094.bobaab
#             FVandMoms48-0094.bobbba
#             FVandMoms48-0094.bobaba
#         0114/
#             FVandMoms48-0114.bobbba
#             FVandMoms48-0114.bobaba
#             FVandMoms48-0114.bobbaa
#             FVandMoms48-0114.bobaaa
#             FVandMoms48-0114.bobaab
#             FVandMoms48-0114.bobabb
#             FVandMoms48-0114.bobbbb
#         0087/
#             FVandMoms48-0087.bobbbb
#             FVandMoms48-0087.bobaba
#             FVandMoms48-0087.bobabb
#             FVandMoms48-0087.bobbba
#             FVandMoms48-0087.bobaaa
#             FVandMoms48-0087.bobbaa
#             FVandMoms48-0087.bobaab
#         0042/
#             FVandMoms48-0042.bobbba
#             FVandMoms48-0042.bobbaa
#             FVandMoms48-0042.bobabb
#             FVandMoms48-0042.bobaab
#             FVandMoms48-0042.bobbbb
#             FVandMoms48-0042.bobaaa
#             FVandMoms48-0042.bobaba
#         0100/
#             FVandMoms48-0100.bobbab
#             FVandMoms48-0100.bobbbb
#             FVandMoms48-0100.bobabb
#             FVandMoms48-0100.bobaaa
#             FVandMoms48-0100.bobbaa
#             FVandMoms48-0100.bobaba
#             FVandMoms48-0100.bobaab
#         0067/
#             FVandMoms48-0067.bobaba
#             FVandMoms48-0067.bobabb
#             FVandMoms48-0067.bobbab
#             FVandMoms48-0067.bobbbb
#             FVandMoms48-0067.bobaaa
#             FVandMoms48-0067.bobaab
#             FVandMoms48-0067.bobbaa
#         0070/
#             FVandMoms48-0070.bobaba
#             FVandMoms48-0070.bobbaa
#             FVandMoms48-0070.bobabb
#             FVandMoms48-0070.bobaab
#             FVandMoms48-0070.bobbbb
#             FVandMoms48-0070.bobbba
#             FVandMoms48-0070.bobaaa
#         0063/
#             FVandMoms48-0063.bobbba
#             FVandMoms48-0063.bobaaa
#             FVandMoms48-0063.bobaab
#             FVandMoms48-0063.bobabb
#             FVandMoms48-0063.bobaba
#             FVandMoms48-0063.bobbab
#             FVandMoms48-0063.bobbaa
#         0089/
#             FVandMoms48-0089.bobaab
#             FVandMoms48-0089.bobbba
#             FVandMoms48-0089.bobbaa
#             FVandMoms48-0089.bobbab
#             FVandMoms48-0089.bobabb
#             FVandMoms48-0089.bobaaa
#             FVandMoms48-0089.bobaba
#         0118/
#             FVandMoms48-0118.bobabb
#             FVandMoms48-0118.bobaba
#             FVandMoms48-0118.bobbab
#             FVandMoms48-0118.bobbbb
#             FVandMoms48-0118.bobaab
#             FVandMoms48-0118.bobbaa
#             FVandMoms48-0118.bobaaa
#         0051/
#             FVandMoms48-0051.bobbbb
#             FVandMoms48-0051.bobbaa
#             FVandMoms48-0051.bobbab
#             FVandMoms48-0051.bobaab
#             FVandMoms48-0051.bobbba
#             FVandMoms48-0051.bobabb
#             FVandMoms48-0051.bobaaa
#         0115/
#             FVandMoms48-0115.bobbba
#             FVandMoms48-0115.bobbab
#             FVandMoms48-0115.bobaaa
#             FVandMoms48-0115.bobaba
#             FVandMoms48-0115.bobabb
#             FVandMoms48-0115.bobaab
#             FVandMoms48-0115.bobbbb
#         0018/
#             FVandMoms48-0018.bobbba
#             FVandMoms48-0018.bobaba
#             FVandMoms48-0018.bobaab
#             FVandMoms48-0018.bobbab
#             FVandMoms48-0018.bobbaa
#             FVandMoms48-0018.bobbbb
#             FVandMoms48-0018.bobaaa
#         0102/
#             FVandMoms48-0102.bobabb
#             FVandMoms48-0102.bobaab
#             FVandMoms48-0102.bobaaa
#             FVandMoms48-0102.bobbab
#             FVandMoms48-0102.bobbbb
#             FVandMoms48-0102.bobaba
#             FVandMoms48-0102.bobbaa
#         0014/
#             FVandMoms48-0014.bobabb
#             FVandMoms48-0014.bobaba
#             FVandMoms48-0014.bobaaa
#             FVandMoms48-0014.bobbba
#             FVandMoms48-0014.bobaab
#             FVandMoms48-0014.bobbab
#             FVandMoms48-0014.bobbbb
#         0027/
#             FVandMoms48-0027.bobbab
#             FVandMoms48-0027.bobbaa
#             FVandMoms48-0027.bobbba
#             FVandMoms48-0027.bobabb
#             FVandMoms48-0027.bobaaa
#             FVandMoms48-0027.bobaab
#             FVandMoms48-0027.bobaba
#         0001/
#             FVandMoms48-0001.bobbba
#             FVandMoms48-0001.bobbab
#             FVandMoms48-0001.bobbbb
#             FVandMoms48-0001.bobaaa
#             FVandMoms48-0001.bobabb
#             FVandMoms48-0001.bobaba
#             FVandMoms48-0001.bobbaa
#         0011/
#             FVandMoms48-0011.bobabb
#             FVandMoms48-0011.bobbaa
#             FVandMoms48-0011.bobbab
#             FVandMoms48-0011.bobaba
#             FVandMoms48-0011.bobaab
#             FVandMoms48-0011.bobbbb
#             FVandMoms48-0011.bobbba
#         0006/
#             FVandMoms48-0006.bobaba
#             FVandMoms48-0006.bobbba
#             FVandMoms48-0006.bobaaa
#             FVandMoms48-0006.bobaab
#             FVandMoms48-0006.bobabb
#             FVandMoms48-0006.bobbbb
#             FVandMoms48-0006.bobbaa
#         0117/
#             FVandMoms48-0117.bobaab
#             FVandMoms48-0117.bobaba
#             FVandMoms48-0117.bobbaa
#             FVandMoms48-0117.bobbba
#             FVandMoms48-0117.bobbab
#             FVandMoms48-0117.bobaaa
#             FVandMoms48-0117.bobabb
#         0132/
#             FVandMoms48-0132.bobbbb
#             FVandMoms48-0132.bobbab
#             FVandMoms48-0132.bobbaa
#             FVandMoms48-0132.bobaba
#             FVandMoms48-0132.bobabb
#             FVandMoms48-0132.bobaaa
#             FVandMoms48-0132.bobaab
#         0043/
#             FVandMoms48-0043.bobbbb
#             FVandMoms48-0043.bobaba
#             FVandMoms48-0043.bobbaa
#             FVandMoms48-0043.bobabb
#             FVandMoms48-0043.bobaaa
#             FVandMoms48-0043.bobbab
#             FVandMoms48-0043.bobbba
#         0133/
#             FVandMoms48-0133.bobabb
#             FVandMoms48-0133.bobbba
#             FVandMoms48-0133.bobaba
#             FVandMoms48-0133.bobbaa
#             FVandMoms48-0133.bobaaa
#             FVandMoms48-0133.bobaab
#             FVandMoms48-0133.bobbbb
#         0025/
#             FVandMoms48-0025.bobaba
#             FVandMoms48-0025.bobaaa
#             FVandMoms48-0025.bobbbb
#             FVandMoms48-0025.bobabb
#             FVandMoms48-0025.bobaab
#             FVandMoms48-0025.bobbab
#             FVandMoms48-0025.bobbba
#         0112/
#             FVandMoms48-0112.bobaab
#             FVandMoms48-0112.bobabb
#             FVandMoms48-0112.bobbab
#             FVandMoms48-0112.bobbaa
#             FVandMoms48-0112.bobbbb
#             FVandMoms48-0112.bobaba
#             FVandMoms48-0112.bobbba
#         0012/
#             FVandMoms48-0012.bobbab
#             FVandMoms48-0012.bobbaa
#             FVandMoms48-0012.bobaba
#             FVandMoms48-0012.bobbba
#             FVandMoms48-0012.bobabb
#             FVandMoms48-0012.bobaaa
#             FVandMoms48-0012.bobbbb
#         0052/
#             FVandMoms48-0052.bobaab
#             FVandMoms48-0052.bobbab
#             FVandMoms48-0052.bobaaa
#             FVandMoms48-0052.bobabb
#             FVandMoms48-0052.bobbbb
#             FVandMoms48-0052.bobbaa
#             FVandMoms48-0052.bobbba
#         0019/
#             FVandMoms48-0019.bobaaa
#             FVandMoms48-0019.bobbba
#             FVandMoms48-0019.bobbab
#             FVandMoms48-0019.bobabb
#             FVandMoms48-0019.bobbbb
#             FVandMoms48-0019.bobbaa
#             FVandMoms48-0019.bobaab
#         0072/
#             FVandMoms48-0072.bobbab
#             FVandMoms48-0072.bobbbb
#             FVandMoms48-0072.bobbba
#             FVandMoms48-0072.bobbaa
#             FVandMoms48-0072.bobaba
#             FVandMoms48-0072.bobabb
#             FVandMoms48-0072.bobaab
#         0080/
#             FVandMoms48-0080.bobbba
#             FVandMoms48-0080.bobabb
#             FVandMoms48-0080.bobaaa
#             FVandMoms48-0080.bobaab
#             FVandMoms48-0080.bobbaa
#             FVandMoms48-0080.bobbbb
#             FVandMoms48-0080.bobbab
#         0066/
#             FVandMoms48-0066.bobaaa
#             FVandMoms48-0066.bobbbb
#             FVandMoms48-0066.bobaab
#             FVandMoms48-0066.bobbaa
#             FVandMoms48-0066.bobbab
#             FVandMoms48-0066.bobbba
#             FVandMoms48-0066.bobaba
#         0123/
#             FVandMoms48-0123.bobbba
#             FVandMoms48-0123.bobbaa
#             FVandMoms48-0123.bobaaa
#             FVandMoms48-0123.bobabb
#             FVandMoms48-0123.bobbbb
#             FVandMoms48-0123.bobaba
#             FVandMoms48-0123.bobbab
#         0041/
#             FVandMoms48-0041.bobbba
#             FVandMoms48-0041.bobaaa
#             FVandMoms48-0041.bobbab
#             FVandMoms48-0041.bobaab
#             FVandMoms48-0041.bobabb
#             FVandMoms48-0041.bobaba
#             FVandMoms48-0041.bobbbb
#         0081/
#             FVandMoms48-0081.bobaab
#             FVandMoms48-0081.bobaaa
#             FVandMoms48-0081.bobabb
#             FVandMoms48-0081.bobbab
#             FVandMoms48-0081.bobbaa
#             FVandMoms48-0081.bobaba
#             FVandMoms48-0081.bobbbb
#         0088/
#             FVandMoms48-0088.bobbaa
#             FVandMoms48-0088.bobbbb
#             FVandMoms48-0088.bobaaa
#             FVandMoms48-0088.bobabb
#             FVandMoms48-0088.bobaab
#             FVandMoms48-0088.bobbab
#             FVandMoms48-0088.bobaba
#         0024/
#             FVandMoms48-0024.bobbba
#             FVandMoms48-0024.bobbbb
#             FVandMoms48-0024.bobbaa
#             FVandMoms48-0024.bobabb
#             FVandMoms48-0024.bobaaa
#             FVandMoms48-0024.bobaab
#             FVandMoms48-0024.bobbab
#         0068/
#             FVandMoms48-0068.bobbbb
#             FVandMoms48-0068.bobabb
#             FVandMoms48-0068.bobaaa
#             FVandMoms48-0068.bobaab
#             FVandMoms48-0068.bobbba
#             FVandMoms48-0068.bobaba
#             FVandMoms48-0068.bobbab
#         0079/
#             FVandMoms48-0079.bobbab
#             FVandMoms48-0079.bobbbb
#             FVandMoms48-0079.bobabb
#             FVandMoms48-0079.bobaba
#             FVandMoms48-0079.bobaab
#             FVandMoms48-0079.bobaaa
#             FVandMoms48-0079.bobbba
#         0029/
#             FVandMoms48-0029.bobaaa
#             FVandMoms48-0029.bobbbb
#             FVandMoms48-0029.bobaba
#             FVandMoms48-0029.bobbab
#             FVandMoms48-0029.bobbaa
#             FVandMoms48-0029.bobaab
#             FVandMoms48-0029.bobbba
#         0141/
#             FVandMoms48-0141.bobaba
#             FVandMoms48-0141.bobabb
#             FVandMoms48-0141.bobbab
#             FVandMoms48-0141.bobbbb
#             FVandMoms48-0141.bobbba
#             FVandMoms48-0141.bobaab
#             FVandMoms48-0141.bobbaa
#         0059/
#             FVandMoms48-0059.bobaaa
#             FVandMoms48-0059.bobbaa
#             FVandMoms48-0059.bobbab
#             FVandMoms48-0059.bobaab
#             FVandMoms48-0059.bobbbb
#             FVandMoms48-0059.bobbba
#             FVandMoms48-0059.bobabb
#         0002/
#             FVandMoms48-0002.bobbba
#             FVandMoms48-0002.bobabb
#             FVandMoms48-0002.bobbab
#             FVandMoms48-0002.bobaaa
#             FVandMoms48-0002.bobbaa
#             FVandMoms48-0002.bobbbb
#             FVandMoms48-0002.bobaba
#         0097/
#             FVandMoms48-0097.bobaaa
#             FVandMoms48-0097.bobbaa
#             FVandMoms48-0097.bobabb
#             FVandMoms48-0097.bobbba
#             FVandMoms48-0097.bobbbb
#             FVandMoms48-0097.bobbab
#             FVandMoms48-0097.bobaab
#         0082/
#             FVandMoms48-0082.bobaab
#             FVandMoms48-0082.bobabb
#             FVandMoms48-0082.bobbaa
#             FVandMoms48-0082.bobbab
#             FVandMoms48-0082.bobaaa
#             FVandMoms48-0082.bobbba
#             FVandMoms48-0082.bobaba
#         0096/
#             FVandMoms48-0096.bobaab
#             FVandMoms48-0096.bobaba
#             FVandMoms48-0096.bobabb
#             FVandMoms48-0096.bobbaa
#             FVandMoms48-0096.bobaaa
#             FVandMoms48-0096.bobbbb
#             FVandMoms48-0096.bobbab
#         0047/
#             FVandMoms48-0047.bobaaa
#             FVandMoms48-0047.bobaab
#             FVandMoms48-0047.bobabb
#             FVandMoms48-0047.bobbaa
#             FVandMoms48-0047.bobbba
#             FVandMoms48-0047.bobbab
#             FVandMoms48-0047.bobaba
#         0110/
#             FVandMoms48-0110.bobaba
#             FVandMoms48-0110.bobbab
#             FVandMoms48-0110.bobbaa
#             FVandMoms48-0110.bobaaa
#             FVandMoms48-0110.bobaab
#             FVandMoms48-0110.bobbbb
#             FVandMoms48-0110.bobbba
#         0084/
#             FVandMoms48-0084.bobaab
#             FVandMoms48-0084.bobaba
#             FVandMoms48-0084.bobbba
#             FVandMoms48-0084.bobaaa
#             FVandMoms48-0084.bobbbb
#             FVandMoms48-0084.bobbab
#             FVandMoms48-0084.bobbaa
#         0036/
#             FVandMoms48-0036.bobabb
#             FVandMoms48-0036.bobaaa
#             FVandMoms48-0036.bobbba
#             FVandMoms48-0036.bobbab
#             FVandMoms48-0036.bobbaa
#             FVandMoms48-0036.bobaab
#             FVandMoms48-0036.bobbbb
#         0125/
#             FVandMoms48-0125.bobaab
#             FVandMoms48-0125.bobaba
#             FVandMoms48-0125.bobaaa
#             FVandMoms48-0125.bobbab
#             FVandMoms48-0125.bobbbb
#             FVandMoms48-0125.bobabb
#             FVandMoms48-0125.bobbba
#         0015/
#             FVandMoms48-0015.bobaaa
#             FVandMoms48-0015.bobbaa
#             FVandMoms48-0015.bobbbb
#             FVandMoms48-0015.bobbab
#             FVandMoms48-0015.bobbba
#             FVandMoms48-0015.bobabb
#             FVandMoms48-0015.bobaab
#         0091/
#             FVandMoms48-0091.bobaba
#             FVandMoms48-0091.bobbbb
#             FVandMoms48-0091.bobaab
#             FVandMoms48-0091.bobabb
#             FVandMoms48-0091.bobbab
#             FVandMoms48-0091.bobaaa
#             FVandMoms48-0091.bobbaa
#         0093/
#             FVandMoms48-0093.bobaba
#             FVandMoms48-0093.bobbbb
#             FVandMoms48-0093.bobaab
#             FVandMoms48-0093.bobbab
#             FVandMoms48-0093.bobabb
#             FVandMoms48-0093.bobbaa
#             FVandMoms48-0093.bobaaa
#         0060/
#             FVandMoms48-0060.bobbbb
#             FVandMoms48-0060.bobaaa
#             FVandMoms48-0060.bobaab
#             FVandMoms48-0060.bobbaa
#             FVandMoms48-0060.bobbab
#             FVandMoms48-0060.bobabb
#             FVandMoms48-0060.bobbba
#         0031/
#             FVandMoms48-0031.bobbaa
#             FVandMoms48-0031.bobbab
#             FVandMoms48-0031.bobabb
#             FVandMoms48-0031.bobaab
#             FVandMoms48-0031.bobaba
#             FVandMoms48-0031.bobbbb
#             FVandMoms48-0031.bobaaa
#         0140/
#             FVandMoms48-0140.bobaab
#             FVandMoms48-0140.bobaaa
#             FVandMoms48-0140.bobbaa
#             FVandMoms48-0140.bobabb
#             FVandMoms48-0140.bobbbb
#             FVandMoms48-0140.bobbab
#             FVandMoms48-0140.bobaba
#         0037/
#             FVandMoms48-0037.bobaaa
#             FVandMoms48-0037.bobaba
#             FVandMoms48-0037.bobabb
#             FVandMoms48-0037.bobbab
#             FVandMoms48-0037.bobbbb
#             FVandMoms48-0037.bobbba
#             FVandMoms48-0037.bobaab
#         0134/
#             FVandMoms48-0134.bobaab
#             FVandMoms48-0134.bobabb
#             FVandMoms48-0134.bobbba
#             FVandMoms48-0134.bobbab
#             FVandMoms48-0134.bobaaa
#             FVandMoms48-0134.bobaba
#             FVandMoms48-0134.bobbaa
#         0124/
#             FVandMoms48-0124.bobaba
#             FVandMoms48-0124.bobbab
#             FVandMoms48-0124.bobbaa
#             FVandMoms48-0124.bobbbb
#             FVandMoms48-0124.bobaab
#             FVandMoms48-0124.bobabb
#             FVandMoms48-0124.bobbba
#         0130/
#             FVandMoms48-0130.bobaab
#             FVandMoms48-0130.bobabb
#             FVandMoms48-0130.bobbbb
#             FVandMoms48-0130.bobaba
#             FVandMoms48-0130.bobbab
#             FVandMoms48-0130.bobbaa
#             FVandMoms48-0130.bobbba
#         0009/
#             FVandMoms48-0009.bobaaa
#             FVandMoms48-0009.bobbbb
#             FVandMoms48-0009.bobbba
#             FVandMoms48-0009.bobaba
#             FVandMoms48-0009.bobbab
#             FVandMoms48-0009.bobabb
#             FVandMoms48-0009.bobbaa
#         0013/
#             FVandMoms48-0013.bobbab
#             FVandMoms48-0013.bobbaa
#             FVandMoms48-0013.bobabb
#             FVandMoms48-0013.bobaab
#             FVandMoms48-0013.bobbba
#             FVandMoms48-0013.bobaaa
#             FVandMoms48-0013.bobbbb
#         0077/
#             FVandMoms48-0077.bobaba
#             FVandMoms48-0077.bobaab
#             FVandMoms48-0077.bobabb
#             FVandMoms48-0077.bobbbb
#             FVandMoms48-0077.bobbaa
#             FVandMoms48-0077.bobbba
#             FVandMoms48-0077.bobaaa
#         0005/
#             FVandMoms48-0005.bobaba
#             FVandMoms48-0005.bobbab
#             FVandMoms48-0005.bobaaa
#             FVandMoms48-0005.bobbba
#             FVandMoms48-0005.bobaab
#             FVandMoms48-0005.bobabb
#             FVandMoms48-0005.bobbbb
#         0000/
#             FVandMoms48-0000.bobbaa
#             FVandMoms48-0000.bobbba
#             FVandMoms48-0000.bobbab
#             FVandMoms48-0000.bobabb
#             FVandMoms48-0000.bobaaa
#             FVandMoms48-0000.bobbbb
#             FVandMoms48-0000.bobaba
#         0049/
#             FVandMoms48-0049.bobaba
#             FVandMoms48-0049.bobbab
#             FVandMoms48-0049.bobbbb
#             FVandMoms48-0049.bobbaa
#             FVandMoms48-0049.bobaaa
#             FVandMoms48-0049.bobaab
#             FVandMoms48-0049.bobbba
#         0038/
#             FVandMoms48-0038.bobbab
#             FVandMoms48-0038.bobabb
#             FVandMoms48-0038.bobaab
#             FVandMoms48-0038.bobaaa
#             FVandMoms48-0038.bobaba
#             FVandMoms48-0038.bobbba
#             FVandMoms48-0038.bobbaa
#         0129/
#             FVandMoms48-0129.bobabb
#             FVandMoms48-0129.bobbab
#             FVandMoms48-0129.bobbaa
#             FVandMoms48-0129.bobaab
#             FVandMoms48-0129.bobbbb
#             FVandMoms48-0129.bobbba
#             FVandMoms48-0129.bobaaa
#         0045/
#             FVandMoms48-0045.bobbab
#             FVandMoms48-0045.bobabb
#             FVandMoms48-0045.bobbba
#             FVandMoms48-0045.bobbaa
#             FVandMoms48-0045.bobbbb
#             FVandMoms48-0045.bobaba
#             FVandMoms48-0045.bobaaa
#         0106/
#             FVandMoms48-0106.bobbaa
#             FVandMoms48-0106.bobbbb
#             FVandMoms48-0106.bobaba
#             FVandMoms48-0106.bobaaa
#             FVandMoms48-0106.bobabb
#             FVandMoms48-0106.bobbab
#             FVandMoms48-0106.bobaab
#         0062/
#             FVandMoms48-0062.bobabb
#             FVandMoms48-0062.bobbba
#             FVandMoms48-0062.bobbbb
#             FVandMoms48-0062.bobbab
#             FVandMoms48-0062.bobaaa
#             FVandMoms48-0062.bobbaa
#             FVandMoms48-0062.bobaba
#         0120/
#             FVandMoms48-0120.bobaab
#             FVandMoms48-0120.bobbab
#             FVandMoms48-0120.bobabb
#             FVandMoms48-0120.bobbba
#             FVandMoms48-0120.bobbaa
#             FVandMoms48-0120.bobbbb
#             FVandMoms48-0120.bobaaa
#         0126/
#             FVandMoms48-0126.bobaaa
#             FVandMoms48-0126.bobbaa
#             FVandMoms48-0126.bobbbb
#             FVandMoms48-0126.bobaab
#             FVandMoms48-0126.bobbba
#             FVandMoms48-0126.bobabb
#             FVandMoms48-0126.bobaba
#         0107/
#             FVandMoms48-0107.bobaba
#             FVandMoms48-0107.bobabb
#             FVandMoms48-0107.bobbab
#             FVandMoms48-0107.bobbbb
#             FVandMoms48-0107.bobbba
#             FVandMoms48-0107.bobbaa
#             FVandMoms48-0107.bobaab
#         0032/
#             FVandMoms48-0032.bobbbb
#             FVandMoms48-0032.bobaba
#             FVandMoms48-0032.bobaaa
#             FVandMoms48-0032.bobbba
#             FVandMoms48-0032.bobbaa
#             FVandMoms48-0032.bobaab
#             FVandMoms48-0032.bobbab
#         0061/
#             FVandMoms48-0061.bobbba
#             FVandMoms48-0061.bobaba
#             FVandMoms48-0061.bobbaa
#             FVandMoms48-0061.bobabb
#             FVandMoms48-0061.bobaab
#             FVandMoms48-0061.bobbab
#             FVandMoms48-0061.bobaaa
#         0073/
#             FVandMoms48-0073.bobabb
#             FVandMoms48-0073.bobbbb
#             FVandMoms48-0073.bobaba
#             FVandMoms48-0073.bobbaa
#             FVandMoms48-0073.bobaaa
#             FVandMoms48-0073.bobaab
#             FVandMoms48-0073.bobbab
#         0034/
#             FVandMoms48-0034.bobaaa
#             FVandMoms48-0034.bobbba
#             FVandMoms48-0034.bobbaa
#             FVandMoms48-0034.bobaba
#             FVandMoms48-0034.bobaab
#             FVandMoms48-0034.bobbab
#             FVandMoms48-0034.bobabb
#         0085/
#             FVandMoms48-0085.bobbaa
#             FVandMoms48-0085.bobabb
#             FVandMoms48-0085.bobaab
#             FVandMoms48-0085.bobbbb
#             FVandMoms48-0085.bobbab
#             FVandMoms48-0085.bobaba
#             FVandMoms48-0085.bobbba
#         0035/
#             FVandMoms48-0035.bobaab
#             FVandMoms48-0035.bobbbb
#             FVandMoms48-0035.bobaaa
#             FVandMoms48-0035.bobbaa
#             FVandMoms48-0035.bobbab
#             FVandMoms48-0035.bobaba
#             FVandMoms48-0035.bobabb
#         0026/
#             FVandMoms48-0026.bobabb
#             FVandMoms48-0026.bobbaa
#             FVandMoms48-0026.bobaaa
#             FVandMoms48-0026.bobaba
#             FVandMoms48-0026.bobbba
#             FVandMoms48-0026.bobbbb
#             FVandMoms48-0026.bobaab
#         0116/
#             FVandMoms48-0116.bobaab
#             FVandMoms48-0116.bobaaa
#             FVandMoms48-0116.bobbaa
#             FVandMoms48-0116.bobaba
#             FVandMoms48-0116.bobbbb
#             FVandMoms48-0116.bobbba
#             FVandMoms48-0116.bobbab
#         0105/
#             FVandMoms48-0105.bobbab
#             FVandMoms48-0105.bobbba
#             FVandMoms48-0105.bobabb
#             FVandMoms48-0105.bobaaa
#             FVandMoms48-0105.bobaab
#             FVandMoms48-0105.bobbbb
#             FVandMoms48-0105.bobaba
#         0056/
#             FVandMoms48-0056.bobbaa
#             FVandMoms48-0056.bobaab
#             FVandMoms48-0056.bobaba
#             FVandMoms48-0056.bobabb
#             FVandMoms48-0056.bobbab
#             FVandMoms48-0056.bobbba
#             FVandMoms48-0056.bobbbb
#         0074/
#             FVandMoms48-0074.bobabb
#             FVandMoms48-0074.bobbba
#             FVandMoms48-0074.bobaba
#             FVandMoms48-0074.bobbab
#             FVandMoms48-0074.bobaaa
#             FVandMoms48-0074.bobaab
#             FVandMoms48-0074.bobbbb
#         0040/
#             FVandMoms48-0040.bobbab
#             FVandMoms48-0040.bobaab
#             FVandMoms48-0040.bobabb
#             FVandMoms48-0040.bobbaa
#             FVandMoms48-0040.bobaaa
#             FVandMoms48-0040.bobbba
#             FVandMoms48-0040.bobaba
#         0058/
#             FVandMoms48-0058.bobbab
#             FVandMoms48-0058.bobbaa
#             FVandMoms48-0058.bobaab
#             FVandMoms48-0058.bobaba
#             FVandMoms48-0058.bobbba
#             FVandMoms48-0058.bobbbb
#             FVandMoms48-0058.bobaaa
#         0007/
#             FVandMoms48-0007.bobabb
#             FVandMoms48-0007.bobbab
#             FVandMoms48-0007.bobaaa
#             FVandMoms48-0007.bobaba
#             FVandMoms48-0007.bobaab
#             FVandMoms48-0007.bobbba
#             FVandMoms48-0007.bobbaa
#         0139/
#             FVandMoms48-0139.bobaab
#             FVandMoms48-0139.bobbbb
#             FVandMoms48-0139.bobbaa
#             FVandMoms48-0139.bobaaa
#             FVandMoms48-0139.bobaba
#             FVandMoms48-0139.bobbab
#             FVandMoms48-0139.bobbba
#         0028/
#             FVandMoms48-0028.bobabb
#             FVandMoms48-0028.bobbaa
#             FVandMoms48-0028.bobaab
#             FVandMoms48-0028.bobaba
#             FVandMoms48-0028.bobbbb
#             FVandMoms48-0028.bobbab
#             FVandMoms48-0028.bobbba
#         0008/
#             FVandMoms48-0008.bobbab
#             FVandMoms48-0008.bobbbb
#             FVandMoms48-0008.bobbaa
#             FVandMoms48-0008.bobaba
#             FVandMoms48-0008.bobabb
#             FVandMoms48-0008.bobaaa
#             FVandMoms48-0008.bobbba
#         0138/
#             FVandMoms48-0138.bobbab
#             FVandMoms48-0138.bobbaa
#             FVandMoms48-0138.bobaab
#             FVandMoms48-0138.bobbba
#             FVandMoms48-0138.bobbbb
#             FVandMoms48-0138.bobabb
#             FVandMoms48-0138.bobaba
#         0053/
#             FVandMoms48-0053.bobabb
#             FVandMoms48-0053.bobbba
#             FVandMoms48-0053.bobaba
#             FVandMoms48-0053.bobaab
#             FVandMoms48-0053.bobbaa
#             FVandMoms48-0053.bobbbb
#             FVandMoms48-0053.bobaaa
#         0055/
#             FVandMoms48-0055.bobabb
#             FVandMoms48-0055.bobbab
#             FVandMoms48-0055.bobbbb
#             FVandMoms48-0055.bobaba
#             FVandMoms48-0055.bobaab
#             FVandMoms48-0055.bobbaa
#             FVandMoms48-0055.bobaaa
#         0030/
#             FVandMoms48-0030.bobabb
#             FVandMoms48-0030.bobbab
#             FVandMoms48-0030.bobaab
#             FVandMoms48-0030.bobbba
#             FVandMoms48-0030.bobbaa
#             FVandMoms48-0030.bobbbb
#             FVandMoms48-0030.bobaaa
#         0090/
#             FVandMoms48-0090.bobaaa
#             FVandMoms48-0090.bobbba
#             FVandMoms48-0090.bobaba
#             FVandMoms48-0090.bobbaa
#             FVandMoms48-0090.bobbab
#             FVandMoms48-0090.bobabb
#             FVandMoms48-0090.bobbbb
#         0075/
#             FVandMoms48-0075.bobabb
#             FVandMoms48-0075.bobaba
#             FVandMoms48-0075.bobaaa
#             FVandMoms48-0075.bobbab
#             FVandMoms48-0075.bobbba
#             FVandMoms48-0075.bobaab
#             FVandMoms48-0075.bobbaa
#         0137/
#             FVandMoms48-0137.bobaba
#             FVandMoms48-0137.bobaab
#             FVandMoms48-0137.bobbab
#             FVandMoms48-0137.bobbbb
#             FVandMoms48-0137.bobabb
#             FVandMoms48-0137.bobbaa
#             FVandMoms48-0137.bobaaa
#         0136/
#             FVandMoms48-0136.bobaaa
#             FVandMoms48-0136.bobbba
#             FVandMoms48-0136.bobaab
#             FVandMoms48-0136.bobaba
#             FVandMoms48-0136.bobbab
#             FVandMoms48-0136.bobbaa
#             FVandMoms48-0136.bobbbb
#         0099/
#             FVandMoms48-0099.bobaab
#             FVandMoms48-0099.bobbaa
#             FVandMoms48-0099.bobabb
#             FVandMoms48-0099.bobbbb
#             FVandMoms48-0099.bobbba
#             FVandMoms48-0099.bobaba
#             FVandMoms48-0099.bobbab
#         0127/
#             FVandMoms48-0127.bobbaa
#             FVandMoms48-0127.bobbab
#             FVandMoms48-0127.bobaab
#             FVandMoms48-0127.bobbbb
#             FVandMoms48-0127.bobbba
#             FVandMoms48-0127.bobabb
#             FVandMoms48-0127.bobaba
#         0054/
#             FVandMoms48-0054.bobaaa
#             FVandMoms48-0054.bobabb
#             FVandMoms48-0054.bobaab
#             FVandMoms48-0054.bobbaa
#             FVandMoms48-0054.bobaba
#             FVandMoms48-0054.bobbbb
#             FVandMoms48-0054.bobbba
#         0020/
#             FVandMoms48-0020.bobbaa
#             FVandMoms48-0020.bobbab
#             FVandMoms48-0020.bobaaa
#             FVandMoms48-0020.bobabb
#             FVandMoms48-0020.bobaba
#             FVandMoms48-0020.bobbba
#             FVandMoms48-0020.bobaab
#         0021/
#             FVandMoms48-0021.bobaba
#             FVandMoms48-0021.bobabb
#             FVandMoms48-0021.bobaab
#             FVandMoms48-0021.bobbbb
#             FVandMoms48-0021.bobaaa
#             FVandMoms48-0021.bobbba
#             FVandMoms48-0021.bobbaa
#         0121/
#             FVandMoms48-0121.bobabb
#             FVandMoms48-0121.bobbba
#             FVandMoms48-0121.bobbab
#             FVandMoms48-0121.bobaba
#             FVandMoms48-0121.bobbaa
#             FVandMoms48-0121.bobaaa
#             FVandMoms48-0121.bobbbb
#         0135/
#             FVandMoms48-0135.bobaaa
#             FVandMoms48-0135.bobabb
#             FVandMoms48-0135.bobbbb
#             FVandMoms48-0135.bobbab
#             FVandMoms48-0135.bobaab
#             FVandMoms48-0135.bobbba
#             FVandMoms48-0135.bobbaa
#         0069/
#             FVandMoms48-0069.bobabb
#             FVandMoms48-0069.bobbba
#             FVandMoms48-0069.bobaaa
#             FVandMoms48-0069.bobbab
#             FVandMoms48-0069.bobaab
#             FVandMoms48-0069.bobbaa
#             FVandMoms48-0069.bobaba
#         0131/
#             FVandMoms48-0131.bobaba
#             FVandMoms48-0131.bobabb
#             FVandMoms48-0131.bobbba
#             FVandMoms48-0131.bobbbb
#             FVandMoms48-0131.bobaab
#             FVandMoms48-0131.bobbab
#             FVandMoms48-0131.bobbaa
#         0128/
#             FVandMoms48-0128.bobaab
#             FVandMoms48-0128.bobaaa
#             FVandMoms48-0128.bobaba
#             FVandMoms48-0128.bobbaa
#             FVandMoms48-0128.bobbab
#             FVandMoms48-0128.bobbba
#             FVandMoms48-0128.bobabb
#         0078/
#             FVandMoms48-0078.bobbbb
#             FVandMoms48-0078.bobbba
#             FVandMoms48-0078.bobaba
#             FVandMoms48-0078.bobaaa
#             FVandMoms48-0078.bobabb
#             FVandMoms48-0078.bobaab
#             FVandMoms48-0078.bobbab
#         0022/
#             FVandMoms48-0022.bobaaa
#             FVandMoms48-0022.bobbbb
#             FVandMoms48-0022.bobaab
#             FVandMoms48-0022.bobabb
#             FVandMoms48-0022.bobbab
#             FVandMoms48-0022.bobaba
#             FVandMoms48-0022.bobbaa
#         0004/
#             FVandMoms48-0004.bobbbb
#             FVandMoms48-0004.bobbaa
#             FVandMoms48-0004.bobbab
#             FVandMoms48-0004.bobaba
#             FVandMoms48-0004.bobabb
#             FVandMoms48-0004.bobbba
#             FVandMoms48-0004.bobaaa
#         0064/
#             FVandMoms48-0064.bobbba
#             FVandMoms48-0064.bobbbb
#             FVandMoms48-0064.bobabb
#             FVandMoms48-0064.bobaba
#             FVandMoms48-0064.bobbaa
#             FVandMoms48-0064.bobaab
#             FVandMoms48-0064.bobaaa
#         0119/
#             FVandMoms48-0119.bobbbb
#             FVandMoms48-0119.bobbba
#             FVandMoms48-0119.bobbaa
#             FVandMoms48-0119.bobabb
#             FVandMoms48-0119.bobaab
#             FVandMoms48-0119.bobbab
#             FVandMoms48-0119.bobaba
#         0050/
#             FVandMoms48-0050.bobbba
#             FVandMoms48-0050.bobaaa
#             FVandMoms48-0050.bobaab
#             FVandMoms48-0050.bobabb
#             FVandMoms48-0050.bobaba
#             FVandMoms48-0050.bobbaa
#             FVandMoms48-0050.bobbab
#         0122/
#             FVandMoms48-0122.bobabb
#             FVandMoms48-0122.bobbaa
#             FVandMoms48-0122.bobbbb
#             FVandMoms48-0122.bobbba
#             FVandMoms48-0122.bobaba
#             FVandMoms48-0122.bobaab
#             FVandMoms48-0122.bobbab
#         0076/
#             FVandMoms48-0076.bobaba
#             FVandMoms48-0076.bobbbb
#             FVandMoms48-0076.bobbab
#             FVandMoms48-0076.bobbba
#             FVandMoms48-0076.bobaab
#             FVandMoms48-0076.bobaaa
#             FVandMoms48-0076.bobbaa
#         0048/
#             FVandMoms48-0048.bobaab
#             FVandMoms48-0048.bobabb
#             FVandMoms48-0048.bobaaa
#             FVandMoms48-0048.bobbba
#             FVandMoms48-0048.bobbbb
#             FVandMoms48-0048.bobbaa
#             FVandMoms48-0048.bobaba

# %% [markdown]
# ### Check permissions

# %%
# !ls -lat pPPM_D4/
# Out:
# total 2208
# drwxrwx---  26 jerichoo wg-astro    4096 Dec  6 15:13 ..
# drwxrwx---   6 jerichoo wg-astro    4096 Dec  6 15:09 .
# drwxrwx---   7 jerichoo wg-astro    4096 Dec  6 15:08 HV
# drwxrwx--- 144 jerichoo wg-astro   12288 Dec  6 14:52 FVandMoms48
# drwxrwx---   2 jerichoo wg-astro   12288 Dec  6 14:52 YProfile
# -rw-rw----   1 jerichoo wg-astro     231 Dec  6 14:52 jobscript.Orcinus
# -rw-rw----   1 jerichoo wg-astro     229 Dec  6 14:52 jobscript.Orcinus~
# -rw-rw----   1 jerichoo wg-astro     369 Dec  6 14:52 jobscript.Render
# -rw-rw----   1 jerichoo wg-astro     369 Dec  6 14:52 jobscript.Render~
# -rw-rw----   1 jerichoo wg-astro 1099709 Dec  6 14:52 PPM2F-star-sakurai-1-22-14.F
# -rw-rw----   1 jerichoo wg-astro 1099708 Dec  6 14:52 PPM2F-star-sakurai-1-22-14.F~
# drwxrwx---   2 jerichoo wg-astro    4096 Dec  6 14:50 reformatting_log

# %%
# !chmod -R o-r pPPM_D4/

# %% [markdown]
# ### Send a random sample to helix

# %%
# %%bash
# cedar=c99fd40c-5545-11e7-beb6-22000b9a448b
# helix=de463ce4-6d04-11e5-ba46-22000b92c6ec
# globus transfer $cedar:/scratch/jerichoo/
